# %% [markdown]
# qn1

# %%
nums = []

for i in range(5):
    number = float(input(f"Enter number {i+1}: "))
    nums.append(number)

# Find the largest number
largest = max(nums)

# Print the result
print("The largest number is:", largest)
